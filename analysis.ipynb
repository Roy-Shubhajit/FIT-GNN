# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num_nodes = [0.8e+5, 1e+5, 1.2e+5, 1.4e+5, 1.6e+5, 1.8e+5, 2e+5, 2.2e+5, 2.4e+5]
mem_in_GB = [24.4, 37, 52, 73.6, 95, 121, 149, 180, 215]

# %%
plt.plot(num_nodes, mem_in_GB, 'o-')
plt.grid(alpha = 0.5)
plt.xlabel('Number of nodes')
plt.ylabel('Memory Utilization (GB)')
plt.show()
